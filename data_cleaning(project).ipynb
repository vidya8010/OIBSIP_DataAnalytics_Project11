# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('AB_NYC_2019.csv')
df.head(20)
# Out:
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 2   3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 4   5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6   5121                                   BlissArtsSpace!     7356
# 7   5178                  Large Furnished Room Near B'way      8967
# 8   5203                Cozy Clean Guest Room - Family Apt     7490
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
# 11  5441                   Central Manhattan/near Broadway     7989
# 12  5803    Lovely Room 1, Garden, Best Area, Legal rental     9744
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = df.columns.str.strip().str.lower()
df['name'] = df['name'].str.title()  
df['price'] = df['price'].astype(float)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.882100e+04  3.882100e+04  38821.000000  38821.000000  38821.000000
# mean   1.810081e+07  6.424582e+07     40.728129    -73.951149    142.332526
# std    1.069372e+07  7.589752e+07      0.054991      0.046693    196.994756
# min    2.539000e+03  2.438000e+03     40.506410    -74.244420      0.000000
# 25%    8.721444e+06  7.029525e+06     40.688640    -73.982460     69.000000
# 50%    1.887286e+07  2.837092e+07     40.721710    -73.954810    101.000000
# 75%    2.756746e+07  1.018905e+08     40.762990    -73.935020    170.000000
# max    3.645581e+07  2.738417e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    38821.000000       38821.000000       38821.000000
# mean         5.869220          29.290255           1.373229
# std         17.389026          48.182900           1.680328
# ...

# %%
df['host_name'] = df['host_name'].str.title().str.strip()
df['neighbourhood_group'] = df['neighbourhood_group'].str.title().str.strip()
df['neighbourhood'] = df['neighbourhood'].str.title().str.strip()

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df['price'] < (Q1 - 1.5 * IQR)) | (df['price'] > (Q3 + 1.5 * IQR)))]

# %%
df.to_csv("cleaned_airbnb_data.csv", index=False)

# %%
print("📊 DATA CLEANING SUMMARY")
print("----------------------------------------")
print("1️⃣ Missing Values Handling:")
print("   • 'name' → filled with 'No Name Provided'")
print("   • 'host_name' → filled with 'Unknown Host'")
print("   • 'last_review' → filled with NaT (No Review Date)")
print("   • 'reviews_per_month' → filled with 0")

print("\n2️⃣ Duplicate Removal:")
print("   • Used drop_duplicates() to remove duplicate rows")

print("\n3️⃣ Standardization:")
print("   • Text columns ('host_name', 'neighbourhood_group', 'neighbourhood') formatted properly")
print("   • Removed extra spaces and applied title case")

print("\n4️⃣ Outlier Detection:")
print("   • Used IQR method to detect and remove outliers in 'price' column")

print("\n5️⃣ Final Dataset:")
print(f"   • Total Rows after cleaning: {len(df)}")
print(f"   • Total Columns: {len(df.columns)}")

print("\n✅ Data cleaned successfully and saved as 'cleaned_airbnb_data.csv'")
# Out:
# 📊 DATA CLEANING SUMMARY
# ----------------------------------------
# 1️⃣ Missing Values Handling:
#    • 'name' → filled with 'No Name Provided'
#    • 'host_name' → filled with 'Unknown Host'
#    • 'last_review' → filled with NaT (No Review Date)
#    • 'reviews_per_month' → filled with 0
#
# 2️⃣ Duplicate Removal:
#    • Used drop_duplicates() to remove duplicate rows
#
# 3️⃣ Standardization:
#    • Text columns ('host_name', 'neighbourhood_group', 'neighbourhood') formatted properly
#    • Removed extra spaces and applied title case
#
# 4️⃣ Outlier Detection:
#    • Used IQR method to detect and remove outliers in 'price' column
#
# 5️⃣ Final Dataset:
#    • Total Rows after cleaning: 36744
#    • Total Columns: 16
#
# ✅ Data cleaned successfully and saved as 'cleaned_airbnb_data.csv'
